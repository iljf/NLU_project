# %% [markdown]
# <a href="https://colab.research.google.com/github/iljf/NLU_project_team1/blob/main/KLUE_ROBERTA_base_iljf_r2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # KLUE - ROBERTA-BASE

# %% [markdown]
# klue/roberta-base 모델을 KLUE 내 STS 데이터셋을 활용하여 모델을 훈련
#
# *   source code : https://github.com/UKPLab/sentence-transformers

# %%
# !pip install transformers sentence-transformers datasets wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting transformers
#   Downloading transformers-4.19.2-py3-none-any.whl (4.2 MB)
#      |████████████████████████████████| 4.2 MB 5.2 MB/s
# Collecting sentence-transformers
#   Downloading sentence-transformers-2.2.0.tar.gz (79 kB)
#      |████████████████████████████████| 79 kB 4.8 MB/s
# Collecting datasets
#   Downloading datasets-2.2.2-py3-none-any.whl (346 kB)
#      |████████████████████████████████| 346 kB 36.3 MB/s
# Collecting wandb
#   Downloading wandb-0.12.17-py2.py3-none-any.whl (1.8 MB)
#      |████████████████████████████████| 1.8 MB 17.0 MB/s
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from transformers) (21.3)
# Collecting huggingface-hub<1.0,>=0.1.0
#   Downloading huggingface_hub-0.7.0-py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 4.0 MB/s
# Collecting pyyaml>=5.1
#   Downloading PyYAML-6.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (596 kB)
#      |████████████████████████████████| 596 kB 41.8 MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.7.0)
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from transformers) (4.11.3)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.21.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Collecting tokenizers!=0.11.3,<0.13,>=0.11.1
#   Downloading tokenizers-0.12.1-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (6.6 MB)
#      |████████████████████████████████| 6.6 MB 47.6 MB/s
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.64.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from huggingface-hub<1.0,>=0.1.0->transformers) (4.2.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.11.0+cu113)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (0.12.0+cu113)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.0.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (1.4.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.7/dist-packages (from sentence-transformers) (3.2.5)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.96-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#      |████████████████████████████████| 1.2 MB 33.7 MB/s
# Requirement already satisfied: pyarrow>=6.0.0 in /usr/local/lib/python3.7/dist-packages (from datasets) (6.0.1)
# Collecting xxhash
#   Downloading xxhash-3.0.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (212 kB)
#      |████████████████████████████████| 212 kB 7.4 MB/s
# Collecting responses<0.19
#   Downloading responses-0.18.0-py3-none-any.whl (38 kB)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.7/dist-packages (from datasets) (0.70.12.2)
# Collecting aiohttp
#   Downloading aiohttp-3.8.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.1 MB)
#      |████████████████████████████████| 1.1 MB 41.1 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from datasets) (1.3.5)
# Collecting dill<0.3.5
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 5.9 MB/s
# Collecting fsspec[http]>=2021.05.0
#   Downloading fsspec-2022.5.0-py3-none-any.whl (140 kB)
#      |████████████████████████████████| 140 kB 29.2 MB/s
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2022.5.18.1)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 37.5 MB/s
# Collecting pathtools
#   Downloading pathtools-0.1.2.tar.gz (11 kB)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Collecting shortuuid>=0.5.0
#   Downloading shortuuid-1.0.9-py3-none-any.whl (9.4 kB)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Collecting setproctitle
#   Downloading setproctitle-1.2.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# Collecting GitPython>=1.0.0
#   Downloading GitPython-3.1.27-py3-none-any.whl (181 kB)
#      |████████████████████████████████| 181 kB 44.3 MB/s
# Collecting docker-pycreds>=0.4.0
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Collecting sentry-sdk>=1.0.0
#   Downloading sentry_sdk-1.5.12-py2.py3-none-any.whl (145 kB)
#      |████████████████████████████████| 145 kB 38.3 MB/s
# Collecting gitdb<5,>=4.0.1
#   Downloading gitdb-4.0.9-py3-none-any.whl (63 kB)
#      |████████████████████████████████| 63 kB 1.6 MB/s
# Collecting smmap<6,>=3.0.1
#   Downloading smmap-5.0.0-py3-none-any.whl (24 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.2-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (94 kB)
#      |████████████████████████████████| 94 kB 1.8 MB/s
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (2.0.12)
# Collecting asynctest==0.13.0
#   Downloading asynctest-0.13.0-py3-none-any.whl (26 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
#      |████████████████████████████████| 144 kB 50.6 MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.7.2-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (271 kB)
#      |████████████████████████████████| 271 kB 50.7 MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->datasets) (21.4.0)
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.2.0-py3-none-any.whl (8.2 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->transformers) (3.8.0)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->datasets) (2022.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sentence-transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision->sentence-transformers) (7.1.2)
# Building wheels for collected packages: sentence-transformers, pathtools
#   Building wheel for sentence-transformers (setup.py) ... done
#   Created wheel for sentence-transformers: filename=sentence_transformers-2.2.0-py3-none-any.whl size=120747 sha256=fc56713cac102805b6e1f8f43c9b3144000a4c5a9ceb84943904e06ee06262a3
#   Stored in directory: /root/.cache/pip/wheels/83/c0/df/b6873ab7aac3f2465aa9144b6b4c41c4391cfecc027c8b07e7
#   Building wheel for pathtools (setup.py) ... done
#   Created wheel for pathtools: filename=pathtools-0.1.2-py3-none-any.whl size=8806 sha256=25f7471657c2af34546b16116cad7fd5db53e64eed09963dfd415325607cd6ea
#   Stored in directory: /root/.cache/pip/wheels/3e/31/09/fa59cef12cdcfecc627b3d24273699f390e71828921b2cbba2
# Successfully built sentence-transformers pathtools
# Installing collected packages: urllib3, multidict, frozenlist, yarl, smmap, pyyaml, asynctest, async-timeout, aiosignal, tokenizers, huggingface-hub, gitdb, fsspec, dill, aiohttp, xxhash, transformers, shortuuid, setproctitle, sentry-sdk, sentencepiece, responses, pathtools, GitPython, docker-pycreds, wandb, sentence-transformers, datasets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
#   Attempting uninstall: pyyaml
#     Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.5.1
#     Uninstalling dill-0.3.5.1:
#       Successfully uninstalled dill-0.3.5.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed GitPython-3.1.27 aiohttp-3.8.1 aiosignal-1.2.0 async-timeout-4.0.2 asynctest-0.13.0 datasets-2.2.2 dill-0.3.4 docker-pycreds-0.4.0 frozenlist-1.3.0 fsspec-2022.5.0 gitdb-4.0.9 huggingface-hub-0.7.0 multidict-6.0.2 pathtools-0.1.2 pyyaml-6.0 responses-0.18.0 sentence-transformers-2.2.0 sentencepiece-0.1.96 sentry-sdk-1.5.12 setproctitle-1.2.3 shortuuid-1.0.9 smmap-5.0.0 tokenizers-0.12.1 transformers-4.19.2 urllib3-1.25.11 wandb-0.12.17 xxhash-3.0.0 yarl-1.7.2

# %%
import pandas as pd
import os
import sys
import re
import pandas as pd
import numpy as np
import random
from sklearn.model_selection import train_test_split
import math
import logging
from datetime import datetime

import torch
import torch.nn as nn
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler, random_split
from datasets import load_dataset
from sentence_transformers import SentenceTransformer,  LoggingHandler, losses, models, util
from sentence_transformers.evaluation import EmbeddingSimilarityEvaluator
from sentence_transformers.readers import InputExample
from sklearn.metrics import f1_score
import torch.nn.functional as F
from torch.optim import AdamW
from torch.nn import CosineSimilarity, MSELoss
from torch.nn.utils import clip_grad_norm_

# %%
#logger 초기화
logging.basicConfig(
    format="%(asctime)s - %(message)s",
    datefmt="%Y-%m-%d %H:%M:%S",
    level=logging.INFO,
    handlers=[LoggingHandler()],
)

# %%
#argument setting
task = "sts"
model_checkpoint = "klue/roberta-base"

# %%
from datasets import load_dataset
dataset = load_dataset('klue', task)
# Out:
# Downloading builder script:   0%|          | 0.00/5.21k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/2.93k [00:00<?, ?B/s]
# Downloading and preparing dataset klue/sts (download: 1.29 MiB, generated: 2.82 MiB, post-processed: Unknown size, total: 4.11 MiB) to /root/.cache/huggingface/datasets/klue/sts/1.0.0/e0fc3bc3de3eb03be2c92d72fd04a60ecc71903f821619cb28ca0e1e29e4233e...
# Downloading data:   0%|          | 0.00/1.35M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/11668 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/519 [00:00<?, ? examples/s]
# Dataset klue downloaded and prepared to /root/.cache/huggingface/datasets/klue/sts/1.0.0/e0fc3bc3de3eb03be2c92d72fd04a60ecc71903f821619cb28ca0e1e29e4233e. Subsequent calls will reuse this data.
#   0%|          | 0/2 [00:00<?, ?it/s]

# %%
type(dataset)
# Out:
# datasets.dataset_dict.DatasetDict

# %%
dataset.keys()
# Out:
# dict_keys(['train', 'validation'])

# %%
dataset.shape
# Out:
# {'train': (11668, 5), 'validation': (519, 5)}

# %%
dataset['train']
# Out:
# Dataset({
#     features: ['guid', 'source', 'sentence1', 'sentence2', 'labels'],
#     num_rows: 11668
# })

# %%
dataset['validation']
# Out:
# Dataset({
#     features: ['guid', 'source', 'sentence1', 'sentence2', 'labels'],
#     num_rows: 519
# })

# %%
# !git clone https://github.com/KLUE-benchmark/KLUE.git
# Out:
# Cloning into 'KLUE'...
# remote: Enumerating objects: 157, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 157 (delta 18), reused 9 (delta 9), pack-reused 133
# Receiving objects: 100% (157/157), 49.11 MiB | 15.29 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Checking out files: 100% (29/29), done.

# %%
KLUE_dataset = pd.read_json('/content/KLUE/klue_benchmark/klue-sts-v1.1/klue-sts-v1.1_train.json')

# %%
KLUE_dataset.shape
# Out:
# (11668, 6)

# %%
KLUE_dataset.head()
# Out:
#                       guid           source  \
# 0  klue-sts-v1_train_00000       airbnb-rtt
# 1  klue-sts-v1_train_00001   policy-sampled
# 2  klue-sts-v1_train_00002  paraKQC-sampled
# 3  klue-sts-v1_train_00003   policy-sampled
# 4  klue-sts-v1_train_00004       airbnb-rtt
#
#                                            sentence1  \
# 0                   숙소 위치는 찾기 쉽고 일반적인 한국의 반지하 숙소입니다.
# 1      위반행위 조사 등을 거부·방해·기피한 자는 500만원 이하 과태료 부과 대상이다.
# 2            회사가 보낸 메일은 이 지메일이 아니라 다른 지메일 계정으로 전달해줘.
# 3  긴급 고용안정지원금은 지역고용대응 등 특별지원금, 지자체별 소상공인 지원사업, 취업...
# 4                        호스트의 답장이 늦으나, 개선될 것으로 보입니다.
#
#                                     sentence2  \
# 0  숙박시설의 위치는 쉽게 찾을 수 있고 한국의 대표적인 반지하 숙박시설입니다.
# 1       시민들 스스로 자발적인 예방 노력을 한 것은 아산 뿐만이 아니었다.
# 2                  사람들이 주로 네이버 메일을 쓰는 이유를 알려줘
# 3   고용보험이 1차 고용안전망이라면, 국민취업지원제도는 2차 고용안전망입니다.
# 4                  호스트 응답이 늦었지만 개선될 것으로 보입니다.
#
#                                               labels  \
# 0  {'label': 3.7, 'real-label': 3.714285714285714...
# 1  {'label': 0.0, 'real-label': 0.0, 'binary-labe...
# 2  {'label': 0.30000000000000004, 'real-label': 0...
# 3  {'label': 0.6000000000000001, 'real-label': 0....
# 4  {'label': 4.7, 'real-label': 4.714285714285714...
#
#                                          annotations
# 0  {'agreement': '0:0:0:2:5:0', 'annotators': ['0...
# 1  {'agreement': '5:0:0:0:0:0', 'annotators': ['1...
# 2  {'agreement': '4:2:0:0:0:0', 'annotators': ['1...
# 3  {'agreement': '4:2:1:0:0:0', 'annotators': ['1...
# 4  {'agreement': '0:0:0:0:2:5', 'annotators': ['1...

# %%
KLUE_dataset.duplicated(['sentence1', 'sentence2']).sum()
# Out:
# 7

# %%
KLUE_dataset = KLUE_dataset.drop_duplicates(['sentence1','sentence2'], keep='first', ignore_index=True)

# %%
labels = KLUE_dataset.labels.to_list()
labels = pd.DataFrame(labels)
print(len(labels))
labels
# Out:
# 11661
#        label  real-label  binary-label
# 0        3.7    3.714286             1
# 1        0.0    0.000000             0
# 2        0.3    0.333333             0
# 3        0.6    0.571429             0
# 4        4.7    4.714286             1
# ...      ...         ...           ...
# 11656    4.0    4.000000             1
# 11657    0.0    0.000000             0
# 11658    3.7    3.666667             1
# 11659    4.7    4.714286             1
# 11660    3.3    3.333333             1
#
# [11661 rows x 3 columns]

# %%
KLUE_dataset = KLUE_dataset[['sentence1', 'sentence2']].join(labels[['real-label']])
KLUE_dataset.head()
# Out:
#                                            sentence1  \
# 0                   숙소 위치는 찾기 쉽고 일반적인 한국의 반지하 숙소입니다.
# 1      위반행위 조사 등을 거부·방해·기피한 자는 500만원 이하 과태료 부과 대상이다.
# 2            회사가 보낸 메일은 이 지메일이 아니라 다른 지메일 계정으로 전달해줘.
# 3  긴급 고용안정지원금은 지역고용대응 등 특별지원금, 지자체별 소상공인 지원사업, 취업...
# 4                        호스트의 답장이 늦으나, 개선될 것으로 보입니다.
#
#                                     sentence2  real-label
# 0  숙박시설의 위치는 쉽게 찾을 수 있고 한국의 대표적인 반지하 숙박시설입니다.    3.714286
# 1       시민들 스스로 자발적인 예방 노력을 한 것은 아산 뿐만이 아니었다.    0.000000
# 2                  사람들이 주로 네이버 메일을 쓰는 이유를 알려줘    0.333333
# 3   고용보험이 1차 고용안전망이라면, 국민취업지원제도는 2차 고용안전망입니다.    0.571429
# 4                  호스트 응답이 늦었지만 개선될 것으로 보입니다.    4.714286

# %%
# !git clone https://github.com/kakaobrain/KorNLUDatasets/
# Out:
# Cloning into 'KorNLUDatasets'...
# remote: Enumerating objects: 16, done.
# remote: Counting objects: 100% (16/16), done.
# remote: Compressing objects: 100% (15/15), done.
# remote: Total 16 (delta 1), reused 16 (delta 1), pack-reused 0
# Unpacking objects: 100% (16/16), done.
# Checking out files: 100% (9/9), done.

# %%
# !git clone https://github.com/warnikchow/paraKQC
# Out:
# Cloning into 'paraKQC'...
# remote: Enumerating objects: 48, done.
# remote: Counting objects: 100% (48/48), done.
# remote: Compressing objects: 100% (45/45), done.
# remote: Total 48 (delta 15), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (48/48), done.

# %%
dir = '/content/KorNLUDatasets/KorSTS/sts-train.tsv'

# %%
Korsts_dataset = pd.read_csv(dir, delimiter="\t+")
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py:311: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   return func(*args, **kwargs)

# %%
Korsts_dataset.shape
# Out:
# (5749, 7)

# %%
Korsts_dataset.head()
# Out:
#            genre filename      year  id  score               sentence1  \
# 0  main-captions   MSRvid  2012test   1   5.00           비행기가 이륙하고 있다.
# 1  main-captions   MSRvid  2012test   4   3.80   한 남자가 큰 플루트를 연주하고 있다.
# 2  main-captions   MSRvid  2012test   5   3.80  한 남자가 피자에 치즈를 뿌려놓고 있다.
# 3  main-captions   MSRvid  2012test   6   2.60        세 남자가 체스를 하고 있다.
# 4  main-captions   MSRvid  2012test   9   4.25      한 남자가 첼로를 연주하고 있다.
#
#                       sentence2
# 0                 비행기가 이륙하고 있다.
# 1             남자가 플루트를 연주하고 있다.
# 2  한 남자가 구운 피자에 치즈 조각을 뿌려놓고 있다.
# 3              두 남자가 체스를 하고 있다.
# 4       자리에 앉은 남자가 첼로를 연주하고 있다.

# %%
Korsts_dataset = Korsts_dataset.drop_duplicates(['sentence1','sentence2'], keep='first', ignore_index=True)

# %%
Korsts_dataset.isnull().sum()
# Out:
# genre        0
# filename     0
# year         0
# id           0
# score        0
# sentence1    0
# sentence2    0
# dtype: int64

# %%
Korsts_dataset.rename(columns = {'score':'real-label'},inplace=True)

# %%
Korsts_dataset = Korsts_dataset[['sentence1', 'sentence2', 'real-label']]
Korsts_dataset.head()
# Out:
#                 sentence1                     sentence2  real-label
# 0           비행기가 이륙하고 있다.                 비행기가 이륙하고 있다.        5.00
# 1   한 남자가 큰 플루트를 연주하고 있다.             남자가 플루트를 연주하고 있다.        3.80
# 2  한 남자가 피자에 치즈를 뿌려놓고 있다.  한 남자가 구운 피자에 치즈 조각을 뿌려놓고 있다.        3.80
# 3        세 남자가 체스를 하고 있다.              두 남자가 체스를 하고 있다.        2.60
# 4      한 남자가 첼로를 연주하고 있다.       자리에 앉은 남자가 첼로를 연주하고 있다.        4.25

# %%
dir2 = '/content/paraKQC/data/paraKQC_v1.txt'

# %%
ParaKQC_raw = pd.read_csv(dir2, sep="\t")

# %%
ParaKQC_raw.head()
# Out:
#    0  0.1  메일을 다 비울까 아니면 안읽은 것만 지울까?
# 0  0    0   메일 중에 안읽은 것만 지울까? 다 지울까?
# 1  0    0            안읽은 메일만 지워 다지워?
# 2  0    0         다 지울까 안읽은 메일만 지울까?
# 3  0    0        전체를 비울까 안읽은 것만 비울까?
# 4  0    0  안읽은 메일만 지울꺼야? 아니면 다 지울꺼야?

# %%
df = pd.concat([KLUE_dataset,Korsts_dataset],axis=0, join='inner', ignore_index=True)

# %%
import html
import regex as re
from bs4 import BeautifulSoup

def preprocess(sentence):
    sen = BeautifulSoup(html.unescape(sentence), 'html.parser').text     # html parse
    sen = sen.replace("\n", " ")                                    # \n
    sen = re.sub('"',' ', sen)                                      # 따옴표 
    sen = re.sub("[^a-zA-Z0-9가-힣]", " ", sen)                  #영문, 한글, 숫자 만
    sen = re.sub('[-=+,#/\?:^$.@*\"※~&%ㆍ·!』\\‘〈〉|\(\)\[\]\<\>`\'…》《]','', sen)    
    return sen



def preprocess_train(df):
    sentence1 = df['sentence1'].tolist()
    sentence2 = df['sentence2'].tolist()
    real_label = df['real-label'].tolist()

    processed1 = []
    processed2 = []

    for sen1 in sentence1:
        processed1.append(preprocess(sen1))
    for sen2 in sentence2:
        processed2.append(preprocess(sen2))
    
    processed_df = pd.DataFrame(list(zip(processed1, processed2, real_label)),
                        columns = ['sentence1', 'sentence2', 'real-label'])


    return processed_df

# %%
df = preprocess_train(df)

# %%
df.shape
# Out:
# (17361, 3)

# %%
df.head()
# Out:
#                                            sentence1  \
# 0                   숙소 위치는 찾기 쉽고 일반적인 한국의 반지하 숙소입니다
# 1      위반행위 조사 등을 거부 방해 기피한 자는 500만원 이하 과태료 부과 대상이다
# 2            회사가 보낸 메일은 이 지메일이 아니라 다른 지메일 계정으로 전달해줘
# 3  긴급 고용안정지원금은 지역고용대응 등 특별지원금  지자체별 소상공인 지원사업  취업...
# 4                        호스트의 답장이 늦으나  개선될 것으로 보입니다
#
#                                     sentence2  real-label
# 0  숙박시설의 위치는 쉽게 찾을 수 있고 한국의 대표적인 반지하 숙박시설입니다     3.714286
# 1       시민들 스스로 자발적인 예방 노력을 한 것은 아산 뿐만이 아니었다     0.000000
# 2                  사람들이 주로 네이버 메일을 쓰는 이유를 알려줘    0.333333
# 3   고용보험이 1차 고용안전망이라면  국민취업지원제도는 2차 고용안전망입니다     0.571429
# 4                  호스트 응답이 늦었지만 개선될 것으로 보입니다     4.714286

# %%
df.tail()
# Out:
#                                      sentence1  \
# 17356                폭풍우 클로다흐가 영국을 강타하면서 심한 강풍
# 17357  리비아 테러리스트들이 공습에 대한 복수로 찍은 수십 명의 이집트 인질들
# 17358                            바레인으로 향하는 대통령
# 17359              중국  인도는 양국 관계를 증진시키겠다고 맹세한다
# 17360           푸틴 대변인   도핑 혐의는 근거 없는 것으로 보인다
#
#                                             sentence2  real-label
# 17356                        메르켈은 나토와 라트비아의 연대를 약속한다          0.0
# 17357  나일강에서 더 많은 시체가 발견되면서 이집트 보트 충돌 사고 사망자 수가 증가한다          0.0
# 17358                      시 주석   에볼라 퇴치를 계속 돕기 위한 중국         0.0
# 17359             중국은 불안한 주식 거래자들을 안심시키기 위해 뒤뚱거리고 있다          0.0
# 17360               가장 최근의 심한 날씨   토네이도 후 텍사스에서 1명 사망         0.0

# %%
test = pd.read_json('/content/KLUE/klue_benchmark/klue-sts-v1.1/klue-sts-v1.1_dev.json')

# %%
test = test.drop_duplicates(['sentence1','sentence2'], keep='first', ignore_index=True)

# %%
labels = test.labels.to_list()
labels = pd.DataFrame(labels)
print(len(labels))
labels
# Out:
# 519
#      label  real-label  binary-label
# 0      4.9    4.857143             1
# 1      1.4    1.428571             0
# 2      1.3    1.285714             0
# 3      3.7    3.714286             1
# 4      2.5    2.500000             0
# ..     ...         ...           ...
# 514    2.2    2.200000             0
# 515    2.8    2.833333             0
# 516    0.3    0.333333             0
# 517    0.3    0.333333             0
# 518    2.9    2.857143             0
#
# [519 rows x 3 columns]

# %%
test = test[['sentence1', 'sentence2']].join(labels[['real-label']])
test.head()
# Out:
#                                            sentence1  \
# 0                           무엇보다도 호스트분들이 너무 친절하셨습니다.
# 1                             주요 관광지 모두 걸어서 이동가능합니다.
# 2  학생들의 균형 있는 영어능력을 향상시킬 수 있는 학교 수업을 유도하기 위해 2018...
# 3                          다만, 도로와 인접해서 거리의 소음이 들려요.
# 4                형이 다시 캐나다 들어가야 하니 가족모임 일정은 바꾸지 마세요.
#
#                                            sentence2  real-label
# 0                            무엇보다도, 호스트들은 매우 친절했습니다.    4.857143
# 1                        위치는 피렌체 중심가까지 걸어서 이동 가능합니다.    1.428571
# 2  영어 영역의 경우 학생들이 한글 해석본을 암기하는 문제를 해소하기 위해 2016학년...    1.285714
# 3                 하지만, 길과 가깝기 때문에 거리의 소음을 들을 수 있습니다.    3.714286
# 4                            가족 모임 일정은 바꾸지 말도록 하십시오.    2.500000

# %%
# device type
if torch.cuda.is_available():
    device = torch.device("cuda")
    print(f"# available GPUs : {torch.cuda.device_count()}")
    print(f"GPU name : {torch.cuda.get_device_name()}")
else:
    device = torch.device("cpu")
print(device)
# Out:
# # available GPUs : 1
# GPU name : Tesla P100-PCIE-16GB
# cuda

# %%
from transformers import AutoTokenizer, AutoModelForSequenceClassification, TrainingArguments, Trainer, AutoModel
from transformers import get_linear_schedule_with_warmup, get_constant_schedule

# %%
model_checkpoint
# Out:
# 'klue/roberta-base'

# %%
tokenizer = AutoTokenizer.from_pretrained("rurupang/roberta-base-finetuned-sts")
# Out:
# Downloading:   0%|          | 0.00/579 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/243k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/735k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/156 [00:00<?, ?B/s]

# %%
class CustomDataset(Dataset):
    def __init__(self, sentence1, sentence2, real_label):
        self.X1 = sentence1 #list str
        self.X2 = sentence2 #list str
        self.Y = real_label #list float

    def __len__(self):
        return len(self.X1)
    
    def __getitem__(self, index):
        return self.X1[index], self.X2[index], self.Y[index]

# %%
def generate_dataset(df, flag):
    sen_one = df['sentence1'].tolist()
    sen_two = df['sentence2'].tolist()
    real_lab = df['real-label'].tolist()
    
    if flag:
        return CustomDataset(sen_one, sen_two, real_lab)
    else:
        return CustomDataset(sen_one, sen_two, lab)

# %%
train, val = train_test_split(df, test_size=0.1, shuffle=True)

# %%
train_dataset = generate_dataset(train, True)
val_dataset = generate_dataset(val, True)
test_dataset = generate_dataset(test, True)

# %%
# seed 설정
seed = 42
random.seed(seed)
torch.manual_seed(seed)
torch.cuda.manual_seed_all(seed)

# %%
max_length = 128

# %%
def CustomCollateFn(batch):
    sen_one_list = []
    sen_two_list = []
    label_list = []


    for sen_one, sen_two, label in batch:
        sen_one_list.append(sen_one)
        sen_two_list.append(sen_two)
        label_list.append(label/5.0)
    
    tokenized_sen_one = tokenizer(sen_one_list, add_special_tokens=True, padding='max_length',
                                truncation=True, max_length=max_length, return_tensors='pt')
    tokenized_sen_two = tokenizer(sen_two_list, add_special_tokens=True, padding='max_length',
                                truncation=True, max_length=max_length, return_tensors='pt')

    label_list = torch.Tensor(label_list)


    return (tokenized_sen_one, tokenized_sen_two, label_list)

def CustomCollateFn_dev(batch):
    sen_one_list = []
    sen_two_list = []
    label_list = []


    for sen_one, sen_two, label in batch:
        sen_one_list.append(sen_one)
        sen_two_list.append(sen_two)
        label_list.append(label)

    tokenized_sen_one = tokenizer(sen_one_list, add_special_tokens=True, padding='max_length',
                                truncation=True, max_length=max_length, return_tensors='pt')
    tokenized_sen_two = tokenizer(sen_two_list, add_special_tokens=True, padding='max_length',
                                truncation=True, max_length=max_length, return_tensors='pt')

    label_list = torch.Tensor(label_list)

    return (tokenized_sen_one, tokenized_sen_two, label_list)

# %%
def mean_pooling_fn(model_output, attention_mask):
    token_embeddings = model_output[0] #First element of model_output contains all token embeddings
    input_mask_expanded = attention_mask.unsqueeze(-1).expand(token_embeddings.size()).float()
    return torch.sum(token_embeddings * input_mask_expanded, 1) / torch.clamp(input_mask_expanded.sum(1), min=1e-8)

# %%
class CustomPooling(nn.Module):
    def __init__(self):
        super(CustomPooling, self).__init__()

        self.robert = AutoModel.from_pretrained("klue/roberta-base")


        self.cos_score = nn.Sequential(
            nn.Identity()
        )
    
    def forward(self, senone, sentwo):
        output_one = self.robert(input_ids=senone['input_ids'], attention_mask=senone['attention_mask'],
                             token_type_ids=senone['token_type_ids'])
        output_two = self.robert(input_ids=sentwo['input_ids'], attention_mask=sentwo['attention_mask'],
                             token_type_ids=sentwo['token_type_ids'])

        pooled_one = mean_pooling_fn(output_one, senone['attention_mask'])
        pooled_two = mean_pooling_fn(output_two, sentwo['attention_mask'])


        cos_sim = torch.cosine_similarity(pooled_one, pooled_two)
        logit = self.cos_score(cos_sim)

        return logit

# %%
def initializer(input_dataloader, epochs):

    model = CustomPooling()
    optimizer = AdamW(model.parameters(), lr=1e-5, eps=1e-8)
    print(f'total step: {len(input_dataloader) * epochs}')

    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps = round(len(input_dataloader)*0.1),
        num_training_steps = len(input_dataloader) * epochs,

    )

    return model, optimizer, scheduler

# %%
def initializer(input_dataloader, epochs):
    """
    설정에 맞춰서 wandb sweep 실행.
    """
    wandb.init(config=sweep_config)
    model = CustomPooling()   
    w_config = wandb.config   

    optimizer = AdamW(model.parameters(), lr = 1e-5, eps = 1e-8) 
    scheduler = get_linear_schedule_with_warmup(
        optimizer,
        num_warmup_steps = round(len(input_dataloader)*0.1),
        num_training_steps = len(input_dataloader) * epochs,

    )
    print(f'total step: {len(input_dataloader) * epochs}') 
    text_table = wandb.Table(columns=["epoch", "step", "text", 'true_label', 'pred_label'])
    wandb.log({f"error-text-{wandb.run.name}" : text_table})
    return model, optimizer, scheduler

# %%
metric_name = "pearsonr"

# %%
model_name = model_checkpoint.split("/")[-1]
output_dir = os.path.join("test-klue", "sts")
logging_dir = os.path.join(output_dir, 'logs')
args = TrainingArguments(
    # checkpoint
    output_dir=output_dir,
    # overwrite_output_dir=True,

    # Model Save & Load
    save_strategy = "epoch", # 'steps'
    load_best_model_at_end=True,
    # save_steps = 500,


    # Dataset
    num_train_epochs=4,
    per_device_train_batch_size=32,
    per_device_eval_batch_size=8,
    
    # Optimizer
    learning_rate=1e-5, # 5e-5
    weight_decay=0.01,  # 0
    # warmup_steps=200,

    # Resularization
    # max_grad_norm = 1.0,
    # label_smoothing_factor=0.1,


    # Evaluation 
    metric_for_best_model='eval_' + metric_name,
    evaluation_strategy = "epoch",


    # Logging
    logging_dir=logging_dir,
    report_to='wandb',
)

# %%
def save_checkpoint(path, model, optimizer, scheduler, epoch, loss):
    file_name = f'/content/drive/MyDrive/CP2/checkpoints/sts_hyper.ckpt2.{epoch}'
    torch.save({
        'epoch':epoch,
        'model_state_dict':model.state_dict(),
        'optimizer_state_dict':optimizer.state_dict(),
        'scheduler_state_dict':scheduler.state_dict(),
        'loss':loss
    }, file_name)

    print(f'SAVING EPOCH {epoch} ...')

# %%
def train(model, loss_fct, scheduler, optimizer, train_dataloader, valid_dataloader, epochs):
    for epoch in range(epochs):
        print(f'****** STARTING TO TRAIN EPOCH #{epoch} ******')

        wandb.watch(model, log="all", log_freq = 10)
        total_loss = 0
        batch_loss = 0
        batch_count = 0

        model.train()
        model.to(device)

        for step, batch in enumerate(train_dataloader):
            batch_count += 1
            batch = tuple(items.to(device) for items in batch)

            (x_batch_one, x_batch_two, y_batch) = batch

            model.zero_grad()

            logit = model(x_batch_one, x_batch_two)
            loss = loss_fct(logit, y_batch)

            batch_loss += loss.item()
            total_loss += loss.item()

            loss.backward()
            clip_grad_norm_(model.parameters(), 1.0)

            optimizer.step()
            scheduler.step()

            if(step % 10 == 0 and step != 0):
                wandb.log({'train_loss': batch_loss / batch_count, 'train_lr': optimizer.param_groups[0]['lr']})
                print(f"Step : {step + 1}, train Loss : {batch_loss / batch_count:.4f}")                      
                # reset 
                batch_loss, batch_count = 0,0

        wandb.log({'total_train_loss': total_loss / (step + 1), 'total_train_lr': optimizer.param_groups[0]['lr'], "epoch" : (epoch + 1)})
  

        print(f"Epoch {epoch} Total Mean Loss : {total_loss/(step+1):.4f}")
        print(f"*****Epoch {epoch} Train Finish*****\n")
        save_checkpoint(".", model, optimizer, scheduler, epoch, total_loss/(step+1))
        torch.cuda.empty_cache()
       
        if valid_dataloader is not None:
            print(f"*****Epoch {epoch} Valid Start*****")
            valid_loss, valid_pearson, valid_f1 = validate(model, loss_fct, valid_dataloader)
            print(f"Epoch {epoch} Valid Loss : {valid_loss} Valid Pearsonr : {valid_pearson} ValidF1 : {valid_f1}")
            print(f"*****Epoch {epoch} Valid Finish*****\n")
  

    print('** Train Completed! **')

# %%
from datasets import list_metrics, load_metric
metrics_list = list_metrics()
len(metrics_list)
print(', '.join(metric for metric in metrics_list))
# Out:
# accuracy, bertscore, bleu, bleurt, cer, chrf, code_eval, comet, competition_math, coval, cuad, exact_match, f1, frugalscore, glue, google_bleu, indic_glue, mae, mahalanobis, matthews_correlation, mauve, mean_iou, meteor, mse, pearsonr, perplexity, precision, recall, roc_auc, rouge, sacrebleu, sari, seqeval, spearmanr, squad, squad_v2, super_glue, ter, wer, wiki_split, xnli, xtreme_s

# %%
metric_name = "pearsonr"
metric_pearsonr = load_metric(metric_name)
metric_name2 = "f1"
metric_f1 = load_metric(metric_name2)
# Out:
# Downloading builder script:   0%|          | 0.00/2.15k [00:00<?, ?B/s]
# Downloading builder script:   0%|          | 0.00/2.32k [00:00<?, ?B/s]

# %%
def compute_metrics(eval_pred):
    predictions, labels = eval_pred
    predictions = predictions[:, 0]
    pr = metric_pearsonr.compute(predictions=predictions,
                                  references=labels)
    return pr

    f1 = metric_f1.compute(predictions=predictions,
                                  references=labels)
    return {'pearsonr' : pr,
             'f1' : f1}

# %%
# !pip install audtorch
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting audtorch
#   Downloading audtorch-0.6.4-py3-none-any.whl (54 kB)
#      |████████████████████████████████| 54 kB 2.0 MB/s
# Requirement already satisfied: torch in /usr/local/lib/python3.7/dist-packages (from audtorch) (1.11.0+cu113)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from audtorch) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from audtorch) (1.21.6)
# Requirement already satisfied: resampy in /usr/local/lib/python3.7/dist-packages (from audtorch) (0.2.2)
# Requirement already satisfied: librosa>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from audtorch) (0.8.1)
# Collecting audiofile
#   Downloading audiofile-1.1.0-py3-none-any.whl (11 kB)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.7/dist-packages (from audtorch) (0.8.9)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from audtorch) (4.64.0)
# Requirement already satisfied: soundfile>=0.10.2 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (0.10.3.post1)
# Requirement already satisfied: audioread>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (2.1.9)
# Requirement already satisfied: decorator>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (4.4.2)
# Requirement already satisfied: pooch>=1.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (1.6.0)
# Requirement already satisfied: scipy>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (1.4.1)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (1.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (21.3)
# Requirement already satisfied: numba>=0.43.0 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (0.51.2)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.7/dist-packages (from librosa>=0.8.0->audtorch) (1.1.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa>=0.8.0->audtorch) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.43.0->librosa>=0.8.0->audtorch) (0.34.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=20.0->librosa>=0.8.0->audtorch) (3.0.9)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa>=0.8.0->audtorch) (2.23.0)
# Requirement already satisfied: appdirs>=1.3.0 in /usr/local/lib/python3.7/dist-packages (from pooch>=1.0->librosa>=0.8.0->audtorch) (1.4.4)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.0->audtorch) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.0->audtorch) (1.25.11)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.0->audtorch) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests>=2.19.0->pooch>=1.0->librosa>=0.8.0->audtorch) (2022.5.18.1)
# Requirement already satisfied: six>=1.3 in /usr/local/lib/python3.7/dist-packages (from resampy->audtorch) (1.15.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa>=0.8.0->audtorch) (3.1.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.7/dist-packages (from soundfile>=0.10.2->librosa>=0.8.0->audtorch) (1.15.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi>=1.0->soundfile>=0.10.2->librosa>=0.8.0->audtorch) (2.21)
# Collecting sox
#   Downloading sox-1.4.1-py2.py3-none-any.whl (39 kB)
# Collecting audeer
#   Downloading audeer-1.18.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->audtorch) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->audtorch) (2.8.2)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch->audtorch) (4.2.0)
# Installing collected packages: sox, audeer, audiofile, audtorch
# Successfully installed audeer-1.18.0 audiofile-1.1.0 audtorch-0.6.4 sox-1.4.1

# %%
from audtorch.metrics.functional import pearsonr
from scipy import stats

# %%
def validate(model, loss_fct, valid_dataloader):

    model.eval()
    model.to(device)

    total_loss = 0
    total_acc = 0
    all_prediction = []
    all_reallabel = []

    for step, batch in enumerate(valid_dataloader):
        batch = tuple(items.to(device) for items in batch)

        (x_batch_one, x_batch_two, batch_y) = batch

        with torch.no_grad():
            logit = model(x_batch_one, x_batch_two)

        logit = logit*5
        loss = loss_fct(logit, batch_y)
        total_loss += loss.item()


        logit = logit[:].cpu()
        batch_y = batch_y.cpu()

        print(f'Step: {step},  Pearson: {pearsonr(logit, batch_y)}')

        all_prediction = all_prediction + logit.tolist()
        all_reallabel = all_reallabel + batch_y.tolist()

    #pearson

    pred = torch.Tensor(all_prediction) # x
    real = torch.Tensor(all_reallabel) # y
    
    pearson = pearsonr(pred, real)
    
    #loss
    total_loss = total_loss / (step+1)

    #f1
    fone = f1_process(pred, real)

    wandb.log({'total_valid_loss': total_loss, "total_f1_score ": fone, "total_pearsonr" : pearson})  
    print('total_valid_loss : ', total_loss, "total_f1_score : ",  fone,  "total_pearsonr :", pearson)  
    return total_loss, pearson, fone

# %%
def f1_process(pred, real):
    bin_real = []
    bin_pred = []

    for index in range(len(real)):
        if real[index] < 3:
            bin_real.append(0)
        else:
            bin_real.append(1)
    
        if pred[index] < 3:
            bin_pred.append(0)
        else:
            bin_pred.append(1)

    return f1_score(bin_real, bin_pred)

# %%
train_dataloader = DataLoader(
    train_dataset,
    batch_size = 32,
    sampler = RandomSampler(train_dataset),
    collate_fn = CustomCollateFn,
)
valid_dataloader = DataLoader(
    val_dataset,
    batch_size = 32,
    sampler = SequentialSampler(val_dataset),
    collate_fn = CustomCollateFn_dev,
)
test_dataloader = DataLoader(
    test_dataset,
    batch_size = 32,
    sampler = SequentialSampler(test_dataset),
    collate_fn = CustomCollateFn_dev,
)

# %%
# !pip install wandb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.12.17)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.27)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb) (1.2.3)
# Requirement already satisfied: protobuf<4.0dev,>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (6.0)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from wandb) (57.4.0)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.9)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.5.12)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (5.0.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2022.5.18.1)

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
id = wandb.util.generate_id()
print(id)
# Out:
# 3e6p2tms

# %%
sweep_config = {
    
    "name" : "sts_r3",   
    "method": "bayes",
    "metric": {
        "name" : "total_pearsonr", 
        "goal" : "maximize"
                },
    
    "parameters": { 
        "epochs" : {
            "distribution" : "categorical",
            "values" : [4]},
        "learning_rate" : {
            "distribution" : "categorical",
            "values" : [1e-5, 2e-5, 5e-5]},                     
        "eps" : {
            "distribution" : "categorical",
            "values" : [1e-8]
        },
        "train_batch_size" : {
            "distribution" : "categorical",
            "values" : [32]
        },
        "valid_batch_size" : {
            "distribution" : "categorical",
            "values" : [32]
        },
        "warm_up_ratio" : {
            "distribution" : "categorical",
            "values" : [0, 0.1]  #[0, 0.1, 0.2]
        },
    },         
    "early_terminate" : {
        "type": "hyperband", # metric이 2번 이상 개선되지 않을 경우 조기 종료
        "min_iter" : 2,
        "eta" : 2
        }
}

# %%
def run_sweeep(config=None):
    """
    설정에 맞춰서 wandb sweep 실행.
    """
    model = CustomPooling() 
    wandb.init(config=config)
    w_config = wandb.config   
    
    optimizer = AdamW(model.parameters(), lr = w_config.learning_rate, eps =  w_config.eps) 
    num_training_steps = w_config.epochs * len(train_dataloader)
    scheduler = get_linear_schedule_with_warmup(optimizer=optimizer, num_warmup_steps= (num_training_steps * w_config.warm_up_ratio),
                                                num_training_steps = num_training_steps)
    loss_fct = MSELoss()
    train(model, loss_fct, scheduler, optimizer, train_dataloader, valid_dataloader, w_config.epochs)

# %%
sweep_id = wandb.sweep(sweep_config, project = "sts_r3")
wandb.agent(sweep_id, run_sweeep, count = 4)
# Out:
# Create sweep with ID: l3jcjy8h
# Sweep URL: https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h
# 2022-05-31 09:13:44 - Starting sweep agent: entity=None, project=None, count=4
# wandb: Agent Starting Run: 629p5gwh with config:
# wandb: 	epochs: 4
# wandb: 	eps: 1e-08
# wandb: 	learning_rate: 1e-05
# wandb: 	train_batch_size: 32
# wandb: 	valid_batch_size: 32
# wandb: 	warm_up_ratio: 0.1
# Downloading:   0%|          | 0.00/546 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/422M [00:00<?, ?B/s]
# Some weights of the model checkpoint at klue/roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# wandb: Currently logged in as: iljf. Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220531_091403-629p5gwh</code>
# Syncing run <strong><a href="https://wandb.ai/iljf/sts_r3/runs/629p5gwh" target="_blank">astral-sweep-1</a></strong> to <a href="https://wandb.ai/iljf/sts_r3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h" target="_blank">https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h</a>
# ****** STARTING TO TRAIN EPOCH #0 ******
# Step : 11, train Loss : 0.1977
# Step : 21, train Loss : 0.2058
# Step : 31, train Loss : 0.1682
# Step : 41, train Loss : 0.1450
# Step : 51, train Loss : 0.1075
# Step : 61, train Loss : 0.0908
# Step : 71, train Loss : 0.0634
# Step : 81, train Loss : 0.0516
# Step : 91, train Loss : 0.0498
# Step : 101, train Loss : 0.0404
# Step : 111, train Loss : 0.0345
# Step : 121, train Loss : 0.0334
# Step : 131, train Loss : 0.0295
# Step : 141, train Loss : 0.0286
# Step : 151, train Loss : 0.0253
# Step : 161, train Loss : 0.0280
# Step : 171, train Loss : 0.0298
# Step : 181, train Loss : 0.0288
# Step : 191, train Loss : 0.0211
# Step : 201, train Loss : 0.0273
# Step : 211, train Loss : 0.0218
# Step : 221, train Loss : 0.0206
# Step : 231, train Loss : 0.0221
# Step : 241, train Loss : 0.0213
# Step : 251, train Loss : 0.0192
# Step : 261, train Loss : 0.0215
# Step : 271, train Loss : 0.0224
# Step : 281, train Loss : 0.0215
# Step : 291, train Loss : 0.0241
# Step : 301, train Loss : 0.0207
# Step : 311, train Loss : 0.0232
# Step : 321, train Loss : 0.0223
# Step : 331, train Loss : 0.0193
# Step : 341, train Loss : 0.0306
# Step : 351, train Loss : 0.0204
# Step : 361, train Loss : 0.0193
# Step : 371, train Loss : 0.0254
# Step : 381, train Loss : 0.0204
# Step : 391, train Loss : 0.0196
# Step : 401, train Loss : 0.0186
# Step : 411, train Loss : 0.0188
# Step : 421, train Loss : 0.0206
# Step : 431, train Loss : 0.0189
# Step : 441, train Loss : 0.0194
# Step : 451, train Loss : 0.0166
# Step : 461, train Loss : 0.0213
# Step : 471, train Loss : 0.0213
# Step : 481, train Loss : 0.0168
# Epoch 0 Total Mean Loss : 0.0415
# *****Epoch 0 Train Finish*****
#
# SAVING EPOCH 0 ...
# *****Epoch 0 Valid Start*****
# Step: 0,  Pearson: tensor([0.9472])
# Step: 1,  Pearson: tensor([0.9461])
# Step: 2,  Pearson: tensor([0.9540])
# Step: 3,  Pearson: tensor([0.8468])
# Step: 4,  Pearson: tensor([0.9219])
# Step: 5,  Pearson: tensor([0.9465])
# Step: 6,  Pearson: tensor([0.9301])
# Step: 7,  Pearson: tensor([0.8938])
# Step: 8,  Pearson: tensor([0.9464])
# Step: 9,  Pearson: tensor([0.9439])
# Step: 10,  Pearson: tensor([0.9620])
# Step: 11,  Pearson: tensor([0.9253])
# Step: 12,  Pearson: tensor([0.9097])
# Step: 13,  Pearson: tensor([0.9601])
# Step: 14,  Pearson: tensor([0.9495])
# Step: 15,  Pearson: tensor([0.9479])
# Step: 16,  Pearson: tensor([0.8410])
# Step: 17,  Pearson: tensor([0.9713])
# Step: 18,  Pearson: tensor([0.9252])
# Step: 19,  Pearson: tensor([0.9095])
# Step: 20,  Pearson: tensor([0.9373])
# Step: 21,  Pearson: tensor([0.9292])
# Step: 22,  Pearson: tensor([0.9199])
# Step: 23,  Pearson: tensor([0.9168])
# Step: 24,  Pearson: tensor([0.9326])
# Step: 25,  Pearson: tensor([0.9259])
# Step: 26,  Pearson: tensor([0.9315])
# Step: 27,  Pearson: tensor([0.9351])
# Step: 28,  Pearson: tensor([0.9282])
# Step: 29,  Pearson: tensor([0.9397])
# Step: 30,  Pearson: tensor([0.8691])
# Step: 31,  Pearson: tensor([0.9485])
# Step: 32,  Pearson: tensor([0.9300])
# Step: 33,  Pearson: tensor([0.9463])
# Step: 34,  Pearson: tensor([0.8707])
# Step: 35,  Pearson: tensor([0.9280])
# Step: 36,  Pearson: tensor([0.8848])
# Step: 37,  Pearson: tensor([0.9578])
# Step: 38,  Pearson: tensor([0.9156])
# Step: 39,  Pearson: tensor([0.8607])
# Step: 40,  Pearson: tensor([0.9526])
# Step: 41,  Pearson: tensor([0.9319])
# Step: 42,  Pearson: tensor([0.9083])
# Step: 43,  Pearson: tensor([0.9320])
# Step: 44,  Pearson: tensor([0.9362])
# Step: 45,  Pearson: tensor([0.9360])
# Step: 46,  Pearson: tensor([0.9242])
# Step: 47,  Pearson: tensor([0.9259])
# Step: 48,  Pearson: tensor([0.8709])
# Step: 49,  Pearson: tensor([0.9091])
# Step: 50,  Pearson: tensor([0.9305])
# Step: 51,  Pearson: tensor([0.9440])
# Step: 52,  Pearson: tensor([0.9443])
# Step: 53,  Pearson: tensor([0.9325])
# Step: 54,  Pearson: tensor([0.9729])
# total_valid_loss :  0.5477224377068606 total_f1_score :  0.9146410401356698 total_pearsonr : tensor([0.9260])
# Epoch 0 Valid Loss : 0.5477224377068606 Valid Pearsonr : tensor([0.9260]) ValidF1 : 0.9146410401356698
# *****Epoch 0 Valid Finish*****
#
# ****** STARTING TO TRAIN EPOCH #1 ******
# Step : 11, train Loss : 0.0132
# Step : 21, train Loss : 0.0128
# Step : 31, train Loss : 0.0161
# Step : 41, train Loss : 0.0135
# Step : 51, train Loss : 0.0143
# Step : 61, train Loss : 0.0150
# Step : 71, train Loss : 0.0143
# Step : 81, train Loss : 0.0138
# Step : 91, train Loss : 0.0165
# Step : 101, train Loss : 0.0122
# Step : 111, train Loss : 0.0141
# Step : 121, train Loss : 0.0130
# Step : 131, train Loss : 0.0165
# Step : 141, train Loss : 0.0164
# Step : 151, train Loss : 0.0115
# Step : 161, train Loss : 0.0144
# Step : 171, train Loss : 0.0150
# Step : 181, train Loss : 0.0135
# Step : 191, train Loss : 0.0147
# Step : 201, train Loss : 0.0131
# Step : 211, train Loss : 0.0149
# Step : 221, train Loss : 0.0144
# Step : 231, train Loss : 0.0134
# Step : 241, train Loss : 0.0181
# Step : 251, train Loss : 0.0126
# Step : 261, train Loss : 0.0138
# Step : 271, train Loss : 0.0138
# Step : 281, train Loss : 0.0139
# Step : 291, train Loss : 0.0155
# Step : 301, train Loss : 0.0138
# Step : 311, train Loss : 0.0170
# Step : 321, train Loss : 0.0136
# Step : 331, train Loss : 0.0132
# Step : 341, train Loss : 0.0139
# Step : 351, train Loss : 0.0147
# Step : 361, train Loss : 0.0124
# Step : 371, train Loss : 0.0155
# Step : 381, train Loss : 0.0146
# Step : 391, train Loss : 0.0131
# Step : 401, train Loss : 0.0142
# Step : 411, train Loss : 0.0155
# Step : 421, train Loss : 0.0156
# Step : 431, train Loss : 0.0116
# Step : 441, train Loss : 0.0136
# Step : 451, train Loss : 0.0133
# Step : 461, train Loss : 0.0152
# Step : 471, train Loss : 0.0129
# Step : 481, train Loss : 0.0140
# Epoch 1 Total Mean Loss : 0.0142
# *****Epoch 1 Train Finish*****
#
# SAVING EPOCH 1 ...
# *****Epoch 1 Valid Start*****
# Step: 0,  Pearson: tensor([0.9574])
# Step: 1,  Pearson: tensor([0.9450])
# Step: 2,  Pearson: tensor([0.9551])
# Step: 3,  Pearson: tensor([0.8610])
# Step: 4,  Pearson: tensor([0.9266])
# Step: 5,  Pearson: tensor([0.9469])
# Step: 6,  Pearson: tensor([0.9397])
# Step: 7,  Pearson: tensor([0.8994])
# Step: 8,  Pearson: tensor([0.9513])
# Step: 9,  Pearson: tensor([0.9500])
# Step: 10,  Pearson: tensor([0.9493])
# Step: 11,  Pearson: tensor([0.9389])
# Step: 12,  Pearson: tensor([0.9123])
# Step: 13,  Pearson: tensor([0.9561])
# Step: 14,  Pearson: tensor([0.9493])
# Step: 15,  Pearson: tensor([0.9592])
# Step: 16,  Pearson: tensor([0.8400])
# Step: 17,  Pearson: tensor([0.9740])
# Step: 18,  Pearson: tensor([0.9278])
# Step: 19,  Pearson: tensor([0.9146])
# Step: 20,  Pearson: tensor([0.9482])
# Step: 21,  Pearson: tensor([0.9357])
# Step: 22,  Pearson: tensor([0.9255])
# Step: 23,  Pearson: tensor([0.9291])
# Step: 24,  Pearson: tensor([0.9409])
# Step: 25,  Pearson: tensor([0.9245])
# Step: 26,  Pearson: tensor([0.9491])
# Step: 27,  Pearson: tensor([0.9465])
# Step: 28,  Pearson: tensor([0.9371])
# Step: 29,  Pearson: tensor([0.9453])
# Step: 30,  Pearson: tensor([0.8886])
# Step: 31,  Pearson: tensor([0.9532])
# Step: 32,  Pearson: tensor([0.9326])
# Step: 33,  Pearson: tensor([0.9504])
# Step: 34,  Pearson: tensor([0.8720])
# Step: 35,  Pearson: tensor([0.9482])
# Step: 36,  Pearson: tensor([0.8772])
# Step: 37,  Pearson: tensor([0.9592])
# Step: 38,  Pearson: tensor([0.9185])
# Step: 39,  Pearson: tensor([0.8806])
# Step: 40,  Pearson: tensor([0.9549])
# Step: 41,  Pearson: tensor([0.9296])
# Step: 42,  Pearson: tensor([0.9061])
# Step: 43,  Pearson: tensor([0.9431])
# Step: 44,  Pearson: tensor([0.9341])
# Step: 45,  Pearson: tensor([0.9390])
# Step: 46,  Pearson: tensor([0.9376])
# Step: 47,  Pearson: tensor([0.9153])
# Step: 48,  Pearson: tensor([0.8825])
# Step: 49,  Pearson: tensor([0.9019])
# Step: 50,  Pearson: tensor([0.9402])
# Step: 51,  Pearson: tensor([0.9502])
# Step: 52,  Pearson: tensor([0.9343])
# Step: 53,  Pearson: tensor([0.9366])
# Step: 54,  Pearson: tensor([0.9783])
# total_valid_loss :  0.49935383715412834 total_f1_score :  0.9175667993177942 total_pearsonr : tensor([0.9310])
# Epoch 1 Valid Loss : 0.49935383715412834 Valid Pearsonr : tensor([0.9310]) ValidF1 : 0.9175667993177942
# *****Epoch 1 Valid Finish*****
#
# ****** STARTING TO TRAIN EPOCH #2 ******
# Step : 11, train Loss : 0.0089
# Step : 21, train Loss : 0.0100
# Step : 31, train Loss : 0.0116
# Step : 41, train Loss : 0.0106
# Step : 51, train Loss : 0.0114
# Step : 61, train Loss : 0.0088
# Step : 71, train Loss : 0.0119
# Step : 81, train Loss : 0.0087
# Step : 91, train Loss : 0.0109
# Step : 101, train Loss : 0.0089
# Step : 111, train Loss : 0.0088
# Step : 121, train Loss : 0.0114
# Step : 131, train Loss : 0.0083
# Step : 141, train Loss : 0.0112
# Step : 151, train Loss : 0.0117
# Step : 161, train Loss : 0.0121
# Step : 171, train Loss : 0.0100
# Step : 181, train Loss : 0.0100
# Step : 191, train Loss : 0.0119
# Step : 201, train Loss : 0.0118
# Step : 211, train Loss : 0.0098
# Step : 221, train Loss : 0.0103
# Step : 231, train Loss : 0.0095
# Step : 241, train Loss : 0.0106
# Step : 251, train Loss : 0.0115
# Step : 261, train Loss : 0.0115
# Step : 271, train Loss : 0.0109
# Step : 281, train Loss : 0.0084
# Step : 291, train Loss : 0.0104
# Step : 301, train Loss : 0.0090
# Step : 311, train Loss : 0.0098
# Step : 321, train Loss : 0.0102
# Step : 331, train Loss : 0.0107
# Step : 341, train Loss : 0.0092
# Step : 351, train Loss : 0.0084
# Step : 361, train Loss : 0.0116
# Step : 371, train Loss : 0.0098
# Step : 381, train Loss : 0.0084
# Step : 391, train Loss : 0.0100
# Step : 401, train Loss : 0.0095
# Step : 411, train Loss : 0.0099
# Step : 421, train Loss : 0.0082
# Step : 431, train Loss : 0.0111
# Step : 441, train Loss : 0.0093
# Step : 451, train Loss : 0.0109
# Step : 461, train Loss : 0.0110
# Step : 471, train Loss : 0.0086
# Step : 481, train Loss : 0.0116
# Epoch 2 Total Mean Loss : 0.0102
# *****Epoch 2 Train Finish*****
#
# SAVING EPOCH 2 ...
# *****Epoch 2 Valid Start*****
# Step: 0,  Pearson: tensor([0.9583])
# Step: 1,  Pearson: tensor([0.9493])
# Step: 2,  Pearson: tensor([0.9592])
# Step: 3,  Pearson: tensor([0.8514])
# Step: 4,  Pearson: tensor([0.9278])
# Step: 5,  Pearson: tensor([0.9536])
# Step: 6,  Pearson: tensor([0.9402])
# Step: 7,  Pearson: tensor([0.8867])
# Step: 8,  Pearson: tensor([0.9498])
# Step: 9,  Pearson: tensor([0.9540])
# Step: 10,  Pearson: tensor([0.9549])
# Step: 11,  Pearson: tensor([0.9412])
# Step: 12,  Pearson: tensor([0.9150])
# Step: 13,  Pearson: tensor([0.9610])
# Step: 14,  Pearson: tensor([0.9547])
# Step: 15,  Pearson: tensor([0.9594])
# Step: 16,  Pearson: tensor([0.8414])
# Step: 17,  Pearson: tensor([0.9720])
# Step: 18,  Pearson: tensor([0.9355])
# Step: 19,  Pearson: tensor([0.9128])
# Step: 20,  Pearson: tensor([0.9487])
# Step: 21,  Pearson: tensor([0.9374])
# Step: 22,  Pearson: tensor([0.9262])
# Step: 23,  Pearson: tensor([0.9231])
# Step: 24,  Pearson: tensor([0.9345])
# Step: 25,  Pearson: tensor([0.9240])
# Step: 26,  Pearson: tensor([0.9426])
# Step: 27,  Pearson: tensor([0.9469])
# Step: 28,  Pearson: tensor([0.9377])
# Step: 29,  Pearson: tensor([0.9405])
# Step: 30,  Pearson: tensor([0.8888])
# Step: 31,  Pearson: tensor([0.9523])
# Step: 32,  Pearson: tensor([0.9352])
# Step: 33,  Pearson: tensor([0.9542])
# Step: 34,  Pearson: tensor([0.8755])
# Step: 35,  Pearson: tensor([0.9453])
# Step: 36,  Pearson: tensor([0.8797])
# Step: 37,  Pearson: tensor([0.9610])
# Step: 38,  Pearson: tensor([0.9222])
# Step: 39,  Pearson: tensor([0.8837])
# Step: 40,  Pearson: tensor([0.9588])
# Step: 41,  Pearson: tensor([0.9286])
# Step: 42,  Pearson: tensor([0.8985])
# Step: 43,  Pearson: tensor([0.9385])
# Step: 44,  Pearson: tensor([0.9383])
# Step: 45,  Pearson: tensor([0.9357])
# Step: 46,  Pearson: tensor([0.9430])
# Step: 47,  Pearson: tensor([0.9200])
# Step: 48,  Pearson: tensor([0.8949])
# Step: 49,  Pearson: tensor([0.8992])
# Step: 50,  Pearson: tensor([0.9329])
# Step: 51,  Pearson: tensor([0.9513])
# Step: 52,  Pearson: tensor([0.9337])
# Step: 53,  Pearson: tensor([0.9317])
# Step: 54,  Pearson: tensor([0.9795])
# total_valid_loss :  0.47823613367297435 total_f1_score :  0.9162844036697247 total_pearsonr : tensor([0.9314])
# Epoch 2 Valid Loss : 0.47823613367297435 Valid Pearsonr : tensor([0.9314]) ValidF1 : 0.9162844036697247
# *****Epoch 2 Valid Finish*****
#
# ****** STARTING TO TRAIN EPOCH #3 ******
# Step : 11, train Loss : 0.0085
# Step : 21, train Loss : 0.0083
# Step : 31, train Loss : 0.0070
# Step : 41, train Loss : 0.0098
# Step : 51, train Loss : 0.0085
# Step : 61, train Loss : 0.0082
# Step : 71, train Loss : 0.0098
# Step : 81, train Loss : 0.0078
# Step : 91, train Loss : 0.0085
# Step : 101, train Loss : 0.0088
# Step : 111, train Loss : 0.0087
# Step : 121, train Loss : 0.0083
# Step : 131, train Loss : 0.0081
# Step : 141, train Loss : 0.0088
# Step : 151, train Loss : 0.0096
# Step : 161, train Loss : 0.0081
# Step : 171, train Loss : 0.0084
# Step : 181, train Loss : 0.0089
# Step : 191, train Loss : 0.0080
# Step : 201, train Loss : 0.0080
# Step : 211, train Loss : 0.0090
# Step : 221, train Loss : 0.0091
# Step : 231, train Loss : 0.0076
# Step : 241, train Loss : 0.0089
# Step : 251, train Loss : 0.0071
# Step : 261, train Loss : 0.0082
# Step : 271, train Loss : 0.0073
# Step : 281, train Loss : 0.0083
# Step : 291, train Loss : 0.0072
# Step : 301, train Loss : 0.0088
# Step : 311, train Loss : 0.0080
# Step : 321, train Loss : 0.0070
# Step : 331, train Loss : 0.0075
# Step : 341, train Loss : 0.0083
# Step : 351, train Loss : 0.0102
# Step : 361, train Loss : 0.0080
# Step : 371, train Loss : 0.0071
# Step : 381, train Loss : 0.0082
# Step : 391, train Loss : 0.0101
# Step : 401, train Loss : 0.0076
# Step : 411, train Loss : 0.0094
# Step : 421, train Loss : 0.0085
# Step : 431, train Loss : 0.0112
# Step : 441, train Loss : 0.0075
# Step : 451, train Loss : 0.0085
# Step : 461, train Loss : 0.0075
# Step : 471, train Loss : 0.0073
# Step : 481, train Loss : 0.0071
# Epoch 3 Total Mean Loss : 0.0084
# *****Epoch 3 Train Finish*****
#
# SAVING EPOCH 3 ...
# *****Epoch 3 Valid Start*****
# Step: 0,  Pearson: tensor([0.9549])
# Step: 1,  Pearson: tensor([0.9518])
# Step: 2,  Pearson: tensor([0.9612])
# Step: 3,  Pearson: tensor([0.8520])
# Step: 4,  Pearson: tensor([0.9231])
# Step: 5,  Pearson: tensor([0.9534])
# Step: 6,  Pearson: tensor([0.9393])
# Step: 7,  Pearson: tensor([0.8900])
# Step: 8,  Pearson: tensor([0.9500])
# Step: 9,  Pearson: tensor([0.9531])
# Step: 10,  Pearson: tensor([0.9558])
# Step: 11,  Pearson: tensor([0.9440])
# Step: 12,  Pearson: tensor([0.9137])
# Step: 13,  Pearson: tensor([0.9606])
# Step: 14,  Pearson: tensor([0.9541])
# Step: 15,  Pearson: tensor([0.9611])
# Step: 16,  Pearson: tensor([0.8435])
# Step: 17,  Pearson: tensor([0.9712])
# Step: 18,  Pearson: tensor([0.9344])
# Step: 19,  Pearson: tensor([0.9129])
# Step: 20,  Pearson: tensor([0.9475])
# Step: 21,  Pearson: tensor([0.9366])
# Step: 22,  Pearson: tensor([0.9311])
# Step: 23,  Pearson: tensor([0.9254])
# Step: 24,  Pearson: tensor([0.9379])
# Step: 25,  Pearson: tensor([0.9250])
# Step: 26,  Pearson: tensor([0.9429])
# Step: 27,  Pearson: tensor([0.9476])
# Step: 28,  Pearson: tensor([0.9348])
# Step: 29,  Pearson: tensor([0.9412])
# Step: 30,  Pearson: tensor([0.8872])
# Step: 31,  Pearson: tensor([0.9516])
# Step: 32,  Pearson: tensor([0.9328])
# Step: 33,  Pearson: tensor([0.9512])
# Step: 34,  Pearson: tensor([0.8749])
# Step: 35,  Pearson: tensor([0.9455])
# Step: 36,  Pearson: tensor([0.8748])
# Step: 37,  Pearson: tensor([0.9612])
# Step: 38,  Pearson: tensor([0.9249])
# Step: 39,  Pearson: tensor([0.8822])
# Step: 40,  Pearson: tensor([0.9602])
# Step: 41,  Pearson: tensor([0.9282])
# Step: 42,  Pearson: tensor([0.8999])
# Step: 43,  Pearson: tensor([0.9402])
# Step: 44,  Pearson: tensor([0.9401])
# Step: 45,  Pearson: tensor([0.9354])
# Step: 46,  Pearson: tensor([0.9420])
# Step: 47,  Pearson: tensor([0.9206])
# Step: 48,  Pearson: tensor([0.8933])
# Step: 49,  Pearson: tensor([0.8988])
# Step: 50,  Pearson: tensor([0.9342])
# Step: 51,  Pearson: tensor([0.9535])
# Step: 52,  Pearson: tensor([0.9348])
# Step: 53,  Pearson: tensor([0.9348])
# Step: 54,  Pearson: tensor([0.9770])
# total_valid_loss :  0.4783468893983147 total_f1_score :  0.9170005724098454 total_pearsonr : tensor([0.9316])
# Epoch 3 Valid Loss : 0.4783468893983147 Valid Pearsonr : tensor([0.9316]) ValidF1 : 0.9170005724098454
# *****Epoch 3 Valid Finish*****
#
# ** Train Completed! **
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▆█</td></tr><tr><td>total_f1_score </td><td>▁█▅▇</td></tr><tr><td>total_pearsonr</td><td>▁▇██</td></tr><tr><td>total_train_loss</td><td>█▂▁▁</td></tr><tr><td>total_train_lr</td><td>█▆▃▁</td></tr><tr><td>total_valid_loss</td><td>█▃▁▁</td></tr><tr><td>train_loss</td><td>█▄▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_lr</td><td>▂▃▅▇███▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>total_f1_score </td><td>0.917</td></tr><tr><td>total_pearsonr</td><td>0.9316</td></tr><tr><td>total_train_loss</td><td>0.00836</td></tr><tr><td>total_train_lr</td><td>0.0</td></tr><tr><td>total_valid_loss</td><td>0.47835</td></tr><tr><td>train_loss</td><td>0.0071</td></tr><tr><td>train_lr</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">astral-sweep-1</strong>: <a href="https://wandb.ai/iljf/sts_r3/runs/629p5gwh" target="_blank">https://wandb.ai/iljf/sts_r3/runs/629p5gwh</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220531_091403-629p5gwh/logs</code>
# wandb: Agent Starting Run: xj799wul with config:
# wandb: 	epochs: 4
# wandb: 	eps: 1e-08
# wandb: 	learning_rate: 2e-05
# wandb: 	train_batch_size: 32
# wandb: 	valid_batch_size: 32
# wandb: 	warm_up_ratio: 0.1
# Some weights of the model checkpoint at klue/roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220531_095655-xj799wul</code>
# Syncing run <strong><a href="https://wandb.ai/iljf/sts_r3/runs/xj799wul" target="_blank">sleek-sweep-2</a></strong> to <a href="https://wandb.ai/iljf/sts_r3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h" target="_blank">https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h</a>
# ****** STARTING TO TRAIN EPOCH #0 ******
# Step : 11, train Loss : 0.1835
# Step : 21, train Loss : 0.1700
# Step : 31, train Loss : 0.1426
# Step : 41, train Loss : 0.1066
# Step : 51, train Loss : 0.0742
# Step : 61, train Loss : 0.0439
# Step : 71, train Loss : 0.0479
# Step : 81, train Loss : 0.0402
# Step : 91, train Loss : 0.0367
# Step : 101, train Loss : 0.0279
# Step : 111, train Loss : 0.0338
# Step : 121, train Loss : 0.0250
# Step : 131, train Loss : 0.0253
# Step : 141, train Loss : 0.0256
# Step : 151, train Loss : 0.0295
# Step : 161, train Loss : 0.0244
# Step : 171, train Loss : 0.0270
# Step : 181, train Loss : 0.0221
# Step : 191, train Loss : 0.0206
# Step : 201, train Loss : 0.0183
# Step : 211, train Loss : 0.0215
# Step : 221, train Loss : 0.0237
# Step : 231, train Loss : 0.0201
# Step : 241, train Loss : 0.0209
# Step : 251, train Loss : 0.0242
# Step : 261, train Loss : 0.0213
# Step : 271, train Loss : 0.0158
# Step : 281, train Loss : 0.0198
# Step : 291, train Loss : 0.0194
# Step : 301, train Loss : 0.0206
# Step : 311, train Loss : 0.0185
# Step : 321, train Loss : 0.0215
# Step : 331, train Loss : 0.0227
# Step : 341, train Loss : 0.0209
# Step : 351, train Loss : 0.0252
# Step : 361, train Loss : 0.0187
# Step : 371, train Loss : 0.0168
# Step : 381, train Loss : 0.0174
# Step : 391, train Loss : 0.0197
# Step : 401, train Loss : 0.0202
# Step : 411, train Loss : 0.0215
# Step : 421, train Loss : 0.0173
# Step : 431, train Loss : 0.0174
# Step : 441, train Loss : 0.0204
# Step : 451, train Loss : 0.0172
# Step : 461, train Loss : 0.0182
# Step : 471, train Loss : 0.0195
# Step : 481, train Loss : 0.0172
# Epoch 0 Total Mean Loss : 0.0351
# *****Epoch 0 Train Finish*****
#
# SAVING EPOCH 0 ...
# *****Epoch 0 Valid Start*****
# Step: 0,  Pearson: tensor([0.9339])
# Step: 1,  Pearson: tensor([0.9497])
# Step: 2,  Pearson: tensor([0.9551])
# Step: 3,  Pearson: tensor([0.8516])
# Step: 4,  Pearson: tensor([0.9247])
# Step: 5,  Pearson: tensor([0.9606])
# Step: 6,  Pearson: tensor([0.9309])
# Step: 7,  Pearson: tensor([0.8945])
# Step: 8,  Pearson: tensor([0.9506])
# Step: 9,  Pearson: tensor([0.9490])
# Step: 10,  Pearson: tensor([0.9481])
# Step: 11,  Pearson: tensor([0.9347])
# Step: 12,  Pearson: tensor([0.9017])
# Step: 13,  Pearson: tensor([0.9648])
# Step: 14,  Pearson: tensor([0.9410])
# Step: 15,  Pearson: tensor([0.9543])
# Step: 16,  Pearson: tensor([0.8532])
# Step: 17,  Pearson: tensor([0.9685])
# Step: 18,  Pearson: tensor([0.9316])
# Step: 19,  Pearson: tensor([0.9188])
# Step: 20,  Pearson: tensor([0.9432])
# Step: 21,  Pearson: tensor([0.9150])
# Step: 22,  Pearson: tensor([0.9214])
# Step: 23,  Pearson: tensor([0.9331])
# Step: 24,  Pearson: tensor([0.9254])
# Step: 25,  Pearson: tensor([0.9337])
# Step: 26,  Pearson: tensor([0.9404])
# Step: 27,  Pearson: tensor([0.9413])
# Step: 28,  Pearson: tensor([0.9461])
# Step: 29,  Pearson: tensor([0.9400])
# Step: 30,  Pearson: tensor([0.8632])
# Step: 31,  Pearson: tensor([0.9589])
# Step: 32,  Pearson: tensor([0.9387])
# Step: 33,  Pearson: tensor([0.9551])
# Step: 34,  Pearson: tensor([0.8695])
# Step: 35,  Pearson: tensor([0.9138])
# Step: 36,  Pearson: tensor([0.8765])
# Step: 37,  Pearson: tensor([0.9573])
# Step: 38,  Pearson: tensor([0.9216])
# Step: 39,  Pearson: tensor([0.8602])
# Step: 40,  Pearson: tensor([0.9516])
# Step: 41,  Pearson: tensor([0.9260])
# Step: 42,  Pearson: tensor([0.9016])
# Step: 43,  Pearson: tensor([0.9302])
# Step: 44,  Pearson: tensor([0.9342])
# Step: 45,  Pearson: tensor([0.9327])
# Step: 46,  Pearson: tensor([0.9182])
# Step: 47,  Pearson: tensor([0.9131])
# Step: 48,  Pearson: tensor([0.8649])
# Step: 49,  Pearson: tensor([0.8946])
# Step: 50,  Pearson: tensor([0.9238])
# Step: 51,  Pearson: tensor([0.9421])
# Step: 52,  Pearson: tensor([0.9370])
# Step: 53,  Pearson: tensor([0.9281])
# Step: 54,  Pearson: tensor([0.9703])
# total_valid_loss :  0.5340689978816292 total_f1_score :  0.9163346613545816 total_pearsonr : tensor([0.9261])
# Epoch 0 Valid Loss : 0.5340689978816292 Valid Pearsonr : tensor([0.9261]) ValidF1 : 0.9163346613545816
# *****Epoch 0 Valid Finish*****
#
# ****** STARTING TO TRAIN EPOCH #1 ******
# Step : 11, train Loss : 0.0119
# Step : 21, train Loss : 0.0116
# Step : 31, train Loss : 0.0121
# Step : 41, train Loss : 0.0108
# Step : 51, train Loss : 0.0111
# Step : 61, train Loss : 0.0124
# Step : 71, train Loss : 0.0111
# Step : 81, train Loss : 0.0112
# Step : 91, train Loss : 0.0100
# Step : 101, train Loss : 0.0109
# Step : 111, train Loss : 0.0111
# Step : 121, train Loss : 0.0107
# Step : 131, train Loss : 0.0123
# Step : 141, train Loss : 0.0142
# Step : 151, train Loss : 0.0128
# Step : 161, train Loss : 0.0113
# Step : 171, train Loss : 0.0143
# Step : 181, train Loss : 0.0122
# Step : 191, train Loss : 0.0109
# Step : 201, train Loss : 0.0094
# Step : 211, train Loss : 0.0118
# Step : 221, train Loss : 0.0121
# Step : 231, train Loss : 0.0119
# Step : 241, train Loss : 0.0110
# Step : 251, train Loss : 0.0112
# Step : 261, train Loss : 0.0131
# Step : 271, train Loss : 0.0101
# Step : 281, train Loss : 0.0117
# Step : 291, train Loss : 0.0119
# Step : 301, train Loss : 0.0151
# Step : 311, train Loss : 0.0136
# Step : 321, train Loss : 0.0119
# Step : 331, train Loss : 0.0113
# Step : 341, train Loss : 0.0136
# Step : 351, train Loss : 0.0115
# Step : 361, train Loss : 0.0120
# Step : 371, train Loss : 0.0119
# Step : 381, train Loss : 0.0117
# Step : 391, train Loss : 0.0111
# Step : 401, train Loss : 0.0131
# Step : 411, train Loss : 0.0150
# Step : 421, train Loss : 0.0120
# Step : 431, train Loss : 0.0106
# Step : 441, train Loss : 0.0109
# Step : 451, train Loss : 0.0135
# Step : 461, train Loss : 0.0112
# Step : 471, train Loss : 0.0115
# Step : 481, train Loss : 0.0123
# Epoch 1 Total Mean Loss : 0.0119
# *****Epoch 1 Train Finish*****
#
# SAVING EPOCH 1 ...
# *****Epoch 1 Valid Start*****
# Step: 0,  Pearson: tensor([0.9576])
# Step: 1,  Pearson: tensor([0.9386])
# Step: 2,  Pearson: tensor([0.9599])
# Step: 3,  Pearson: tensor([0.8603])
# Step: 4,  Pearson: tensor([0.9274])
# Step: 5,  Pearson: tensor([0.9465])
# Step: 6,  Pearson: tensor([0.9454])
# Step: 7,  Pearson: tensor([0.8814])
# Step: 8,  Pearson: tensor([0.9504])
# Step: 9,  Pearson: tensor([0.9506])
# Step: 10,  Pearson: tensor([0.9528])
# Step: 11,  Pearson: tensor([0.9400])
# Step: 12,  Pearson: tensor([0.9113])
# Step: 13,  Pearson: tensor([0.9572])
# Step: 14,  Pearson: tensor([0.9377])
# Step: 15,  Pearson: tensor([0.9574])
# Step: 16,  Pearson: tensor([0.8485])
# Step: 17,  Pearson: tensor([0.9725])
# Step: 18,  Pearson: tensor([0.9440])
# Step: 19,  Pearson: tensor([0.9255])
# Step: 20,  Pearson: tensor([0.9459])
# Step: 21,  Pearson: tensor([0.9237])
# Step: 22,  Pearson: tensor([0.9283])
# Step: 23,  Pearson: tensor([0.9266])
# Step: 24,  Pearson: tensor([0.9381])
# Step: 25,  Pearson: tensor([0.9148])
# Step: 26,  Pearson: tensor([0.9308])
# Step: 27,  Pearson: tensor([0.9509])
# Step: 28,  Pearson: tensor([0.9503])
# Step: 29,  Pearson: tensor([0.9472])
# Step: 30,  Pearson: tensor([0.8783])
# Step: 31,  Pearson: tensor([0.9606])
# Step: 32,  Pearson: tensor([0.9324])
# Step: 33,  Pearson: tensor([0.9566])
# Step: 34,  Pearson: tensor([0.8666])
# Step: 35,  Pearson: tensor([0.9419])
# Step: 36,  Pearson: tensor([0.8795])
# Step: 37,  Pearson: tensor([0.9599])
# Step: 38,  Pearson: tensor([0.9183])
# Step: 39,  Pearson: tensor([0.8796])
# Step: 40,  Pearson: tensor([0.9562])
# Step: 41,  Pearson: tensor([0.9210])
# Step: 42,  Pearson: tensor([0.9036])
# Step: 43,  Pearson: tensor([0.9421])
# Step: 44,  Pearson: tensor([0.9309])
# Step: 45,  Pearson: tensor([0.9346])
# Step: 46,  Pearson: tensor([0.9337])
# Step: 47,  Pearson: tensor([0.9078])
# Step: 48,  Pearson: tensor([0.8942])
# Step: 49,  Pearson: tensor([0.8990])
# Step: 50,  Pearson: tensor([0.9269])
# Step: 51,  Pearson: tensor([0.9528])
# Step: 52,  Pearson: tensor([0.9341])
# Step: 53,  Pearson: tensor([0.9380])
# Step: 54,  Pearson: tensor([0.9698])
# total_valid_loss :  0.49968579492785714 total_f1_score :  0.9115801483171705 total_pearsonr : tensor([0.9300])
# Epoch 1 Valid Loss : 0.49968579492785714 Valid Pearsonr : tensor([0.9300]) ValidF1 : 0.9115801483171705
# *****Epoch 1 Valid Finish*****
#
# ****** STARTING TO TRAIN EPOCH #2 ******
# Step : 11, train Loss : 0.0072
# Step : 21, train Loss : 0.0072
# Step : 31, train Loss : 0.0076
# Step : 41, train Loss : 0.0070
# Step : 51, train Loss : 0.0061
# Step : 61, train Loss : 0.0063
# Step : 71, train Loss : 0.0065
# Step : 81, train Loss : 0.0069
# Step : 91, train Loss : 0.0061
# Step : 101, train Loss : 0.0085
# Step : 111, train Loss : 0.0068
# Step : 121, train Loss : 0.0061
# Step : 131, train Loss : 0.0076
# Step : 141, train Loss : 0.0065
# Step : 151, train Loss : 0.0068
# Step : 161, train Loss : 0.0083
# Step : 171, train Loss : 0.0074
# Step : 181, train Loss : 0.0065
# Step : 191, train Loss : 0.0064
# Step : 201, train Loss : 0.0082
# Step : 211, train Loss : 0.0064
# Step : 221, train Loss : 0.0079
# Step : 231, train Loss : 0.0072
# Step : 241, train Loss : 0.0080
# Step : 251, train Loss : 0.0095
# Step : 261, train Loss : 0.0080
# Step : 271, train Loss : 0.0086
# Step : 281, train Loss : 0.0079
# Step : 291, train Loss : 0.0071
# Step : 301, train Loss : 0.0066
# Step : 311, train Loss : 0.0069
# Step : 321, train Loss : 0.0070
# Step : 331, train Loss : 0.0065
# Step : 341, train Loss : 0.0057
# Step : 351, train Loss : 0.0075
# Step : 361, train Loss : 0.0062
# Step : 371, train Loss : 0.0079
# Step : 381, train Loss : 0.0061
# Step : 391, train Loss : 0.0061
# Step : 401, train Loss : 0.0081
# Step : 411, train Loss : 0.0071
# Step : 421, train Loss : 0.0068
# Step : 431, train Loss : 0.0070
# Step : 441, train Loss : 0.0076
# Step : 451, train Loss : 0.0069
# Step : 461, train Loss : 0.0069
# Step : 471, train Loss : 0.0073
# Step : 481, train Loss : 0.0078
# Epoch 2 Total Mean Loss : 0.0071
# *****Epoch 2 Train Finish*****
#
# SAVING EPOCH 2 ...
# *****Epoch 2 Valid Start*****
# Step: 0,  Pearson: tensor([0.9554])
# Step: 1,  Pearson: tensor([0.9427])
# Step: 2,  Pearson: tensor([0.9585])
# Step: 3,  Pearson: tensor([0.8499])
# Step: 4,  Pearson: tensor([0.9201])
# Step: 5,  Pearson: tensor([0.9517])
# Step: 6,  Pearson: tensor([0.9382])
# Step: 7,  Pearson: tensor([0.8821])
# Step: 8,  Pearson: tensor([0.9455])
# Step: 9,  Pearson: tensor([0.9556])
# Step: 10,  Pearson: tensor([0.9478])
# Step: 11,  Pearson: tensor([0.9492])
# Step: 12,  Pearson: tensor([0.9035])
# Step: 13,  Pearson: tensor([0.9594])
# Step: 14,  Pearson: tensor([0.9430])
# Step: 15,  Pearson: tensor([0.9580])
# Step: 16,  Pearson: tensor([0.8507])
# Step: 17,  Pearson: tensor([0.9736])
# Step: 18,  Pearson: tensor([0.9467])
# Step: 19,  Pearson: tensor([0.9145])
# Step: 20,  Pearson: tensor([0.9473])
# Step: 21,  Pearson: tensor([0.9326])
# Step: 22,  Pearson: tensor([0.9395])
# Step: 23,  Pearson: tensor([0.9230])
# Step: 24,  Pearson: tensor([0.9379])
# Step: 25,  Pearson: tensor([0.9163])
# Step: 26,  Pearson: tensor([0.9472])
# Step: 27,  Pearson: tensor([0.9451])
# Step: 28,  Pearson: tensor([0.9448])
# Step: 29,  Pearson: tensor([0.9477])
# Step: 30,  Pearson: tensor([0.8884])
# Step: 31,  Pearson: tensor([0.9502])
# Step: 32,  Pearson: tensor([0.9337])
# Step: 33,  Pearson: tensor([0.9523])
# Step: 34,  Pearson: tensor([0.8658])
# Step: 35,  Pearson: tensor([0.9401])
# Step: 36,  Pearson: tensor([0.8765])
# Step: 37,  Pearson: tensor([0.9630])
# Step: 38,  Pearson: tensor([0.9218])
# Step: 39,  Pearson: tensor([0.8811])
# Step: 40,  Pearson: tensor([0.9556])
# Step: 41,  Pearson: tensor([0.9131])
# Step: 42,  Pearson: tensor([0.9021])
# Step: 43,  Pearson: tensor([0.9370])
# Step: 44,  Pearson: tensor([0.9403])
# Step: 45,  Pearson: tensor([0.9371])
# Step: 46,  Pearson: tensor([0.9240])
# Step: 47,  Pearson: tensor([0.9072])
# Step: 48,  Pearson: tensor([0.8936])
# Step: 49,  Pearson: tensor([0.8987])
# Step: 50,  Pearson: tensor([0.9270])
# Step: 51,  Pearson: tensor([0.9527])
# Step: 52,  Pearson: tensor([0.9370])
# Step: 53,  Pearson: tensor([0.9326])
# Step: 54,  Pearson: tensor([0.9712])
# total_valid_loss :  0.49348998069763184 total_f1_score :  0.9164759725400459 total_pearsonr : tensor([0.9299])
# Epoch 2 Valid Loss : 0.49348998069763184 Valid Pearsonr : tensor([0.9299]) ValidF1 : 0.9164759725400459
# *****Epoch 2 Valid Finish*****
#
# ****** STARTING TO TRAIN EPOCH #3 ******
# Step : 11, train Loss : 0.0055
# Step : 21, train Loss : 0.0058
# Step : 31, train Loss : 0.0051
# Step : 41, train Loss : 0.0049
# Step : 51, train Loss : 0.0060
# Step : 61, train Loss : 0.0050
# Step : 71, train Loss : 0.0055
# Step : 81, train Loss : 0.0044
# Step : 91, train Loss : 0.0052
# Step : 101, train Loss : 0.0051
# Step : 111, train Loss : 0.0057
# Step : 121, train Loss : 0.0049
# Step : 131, train Loss : 0.0062
# Step : 141, train Loss : 0.0056
# Step : 151, train Loss : 0.0058
# Step : 161, train Loss : 0.0051
# Step : 171, train Loss : 0.0061
# Step : 181, train Loss : 0.0053
# Step : 191, train Loss : 0.0057
# Step : 201, train Loss : 0.0058
# Step : 211, train Loss : 0.0068
# Step : 221, train Loss : 0.0049
# Step : 231, train Loss : 0.0053
# Step : 241, train Loss : 0.0053
# Step : 251, train Loss : 0.0052
# Step : 261, train Loss : 0.0053
# Step : 271, train Loss : 0.0054
# Step : 281, train Loss : 0.0064
# Step : 291, train Loss : 0.0061
# Step : 301, train Loss : 0.0051
# Step : 311, train Loss : 0.0048
# Step : 321, train Loss : 0.0052
# Step : 331, train Loss : 0.0053
# Step : 341, train Loss : 0.0055
# Step : 351, train Loss : 0.0052
# Step : 361, train Loss : 0.0040
# Step : 371, train Loss : 0.0053
# Step : 381, train Loss : 0.0046
# Step : 391, train Loss : 0.0047
# Step : 401, train Loss : 0.0048
# Step : 411, train Loss : 0.0039
# Step : 421, train Loss : 0.0062
# Step : 431, train Loss : 0.0051
# Step : 441, train Loss : 0.0056
# Step : 451, train Loss : 0.0058
# Step : 461, train Loss : 0.0049
# Step : 471, train Loss : 0.0047
# Step : 481, train Loss : 0.0055
# Epoch 3 Total Mean Loss : 0.0053
# *****Epoch 3 Train Finish*****
#
# SAVING EPOCH 3 ...
# *****Epoch 3 Valid Start*****
# Step: 0,  Pearson: tensor([0.9547])
# Step: 1,  Pearson: tensor([0.9446])
# Step: 2,  Pearson: tensor([0.9604])
# Step: 3,  Pearson: tensor([0.8541])
# Step: 4,  Pearson: tensor([0.9220])
# Step: 5,  Pearson: tensor([0.9550])
# Step: 6,  Pearson: tensor([0.9486])
# Step: 7,  Pearson: tensor([0.8774])
# Step: 8,  Pearson: tensor([0.9511])
# Step: 9,  Pearson: tensor([0.9571])
# Step: 10,  Pearson: tensor([0.9527])
# Step: 11,  Pearson: tensor([0.9474])
# Step: 12,  Pearson: tensor([0.9099])
# Step: 13,  Pearson: tensor([0.9615])
# Step: 14,  Pearson: tensor([0.9457])
# Step: 15,  Pearson: tensor([0.9602])
# Step: 16,  Pearson: tensor([0.8439])
# Step: 17,  Pearson: tensor([0.9726])
# Step: 18,  Pearson: tensor([0.9478])
# Step: 19,  Pearson: tensor([0.9199])
# Step: 20,  Pearson: tensor([0.9477])
# Step: 21,  Pearson: tensor([0.9297])
# Step: 22,  Pearson: tensor([0.9386])
# Step: 23,  Pearson: tensor([0.9258])
# Step: 24,  Pearson: tensor([0.9406])
# Step: 25,  Pearson: tensor([0.9197])
# Step: 26,  Pearson: tensor([0.9398])
# Step: 27,  Pearson: tensor([0.9489])
# Step: 28,  Pearson: tensor([0.9487])
# Step: 29,  Pearson: tensor([0.9493])
# Step: 30,  Pearson: tensor([0.8825])
# Step: 31,  Pearson: tensor([0.9505])
# Step: 32,  Pearson: tensor([0.9280])
# Step: 33,  Pearson: tensor([0.9497])
# Step: 34,  Pearson: tensor([0.8682])
# Step: 35,  Pearson: tensor([0.9435])
# Step: 36,  Pearson: tensor([0.8698])
# Step: 37,  Pearson: tensor([0.9619])
# Step: 38,  Pearson: tensor([0.9226])
# Step: 39,  Pearson: tensor([0.8889])
# Step: 40,  Pearson: tensor([0.9573])
# Step: 41,  Pearson: tensor([0.9181])
# Step: 42,  Pearson: tensor([0.8965])
# Step: 43,  Pearson: tensor([0.9372])
# Step: 44,  Pearson: tensor([0.9343])
# Step: 45,  Pearson: tensor([0.9299])
# Step: 46,  Pearson: tensor([0.9350])
# Step: 47,  Pearson: tensor([0.9078])
# Step: 48,  Pearson: tensor([0.9012])
# Step: 49,  Pearson: tensor([0.9065])
# Step: 50,  Pearson: tensor([0.9340])
# Step: 51,  Pearson: tensor([0.9519])
# Step: 52,  Pearson: tensor([0.9421])
# Step: 53,  Pearson: tensor([0.9402])
# Step: 54,  Pearson: tensor([0.9677])
# total_valid_loss :  0.4803016733039509 total_f1_score :  0.9155657668006892 total_pearsonr : tensor([0.9313])
# Epoch 3 Valid Loss : 0.4803016733039509 Valid Pearsonr : tensor([0.9313]) ValidF1 : 0.9155657668006892
# *****Epoch 3 Valid Finish*****
#
# ** Train Completed! **
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: left ; width: auto;} td:nth-child(2) {text-align: left ; width: 100%}
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; justify-content: flex-start; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>epoch</td><td>▁▃▆█</td></tr><tr><td>total_f1_score </td><td>█▁█▇</td></tr><tr><td>total_pearsonr</td><td>▁▆▆█</td></tr><tr><td>total_train_loss</td><td>█▃▁▁</td></tr><tr><td>total_train_lr</td><td>█▆▃▁</td></tr><tr><td>total_valid_loss</td><td>█▄▃▁</td></tr><tr><td>train_loss</td><td>█▃▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>train_lr</td><td>▂▃▅▇███▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▂▂▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>epoch</td><td>4</td></tr><tr><td>total_f1_score </td><td>0.91557</td></tr><tr><td>total_pearsonr</td><td>0.93131</td></tr><tr><td>total_train_loss</td><td>0.00532</td></tr><tr><td>total_train_lr</td><td>0.0</td></tr><tr><td>total_valid_loss</td><td>0.4803</td></tr><tr><td>train_loss</td><td>0.00554</td></tr><tr><td>train_lr</td><td>0.0</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">sleek-sweep-2</strong>: <a href="https://wandb.ai/iljf/sts_r3/runs/xj799wul" target="_blank">https://wandb.ai/iljf/sts_r3/runs/xj799wul</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220531_095655-xj799wul/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: jezbg7qk with config:
# wandb: 	epochs: 4
# wandb: 	eps: 1e-08
# wandb: 	learning_rate: 2e-05
# wandb: 	train_batch_size: 32
# wandb: 	valid_batch_size: 32
# wandb: 	warm_up_ratio: 0.1
# Some weights of the model checkpoint at klue/roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220531_103922-jezbg7qk</code>
# Syncing run <strong><a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">misty-sweep-3</a></strong> to <a href="https://wandb.ai/iljf/sts_r3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h" target="_blank">https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h</a>
# ****** STARTING TO TRAIN EPOCH #0 ******
# Step : 11, train Loss : 0.1994
# Step : 21, train Loss : 0.1806
# Step : 31, train Loss : 0.1338
# Step : 41, train Loss : 0.1095
# Step : 51, train Loss : 0.0624
# Step : 61, train Loss : 0.0518
# Step : 71, train Loss : 0.0422
# Step : 81, train Loss : 0.0389
# Step : 91, train Loss : 0.0345
# Step : 101, train Loss : 0.0333
# Step : 111, train Loss : 0.0299
# Step : 121, train Loss : 0.0252
# Step : 131, train Loss : 0.0263
# Step : 141, train Loss : 0.0255
# Step : 151, train Loss : 0.0276
# Step : 161, train Loss : 0.0220
# Step : 171, train Loss : 0.0235
# Step : 181, train Loss : 0.0230
# Step : 191, train Loss : 0.0218
# Step : 201, train Loss : 0.0215
# Step : 211, train Loss : 0.0197
# Step : 221, train Loss : 0.0235
# Step : 231, train Loss : 0.0170
# Step : 241, train Loss : 0.0241
# Step : 251, train Loss : 0.0215
# Step : 261, train Loss : 0.0223
# Step : 271, train Loss : 0.0214
# Step : 281, train Loss : 0.0222
# wandb: Ctrl + C detected. Stopping sweep.

# %%
def predict(model, test_dataloader):
    model.eval()
    model.to(device)

    all_prediction = []
    all_reallabel = []

    for step, batch in enumerate(test_dataloader):

        batch = tuple(items.to(device) for items in batch)

        (x_batch_one, x_batch_two, batch_y) = batch

        with torch.no_grad():
            logit = model(x_batch_one, x_batch_two)
        logit = logit*5
        logit = logit.cpu()
        batch_y = batch_y.cpu()

        all_prediction = all_prediction + logit.tolist()
        all_reallabel = all_reallabel + batch_y.tolist()

    pred = torch.Tensor(all_prediction) # x
    real = torch.Tensor(all_reallabel) # y
    
    pearson = pearsonr(pred, real) #stats.spearmanr(pred, real)

    #f1
    fone = f1_process(pred, real)

    return pearson, fone

# %%
ckpt1 = '/content/drive/MyDrive/CP2/checkpoints/sts_hyper.ckpt2.0'
ckpt2 = '/content/drive/MyDrive/CP2/checkpoints/sts_hyper.ckpt2.1'
ckpt3 = '/content/drive/MyDrive/CP2/checkpoints/sts_hyper.ckpt2.2'
ckpt4 = '/content/drive/MyDrive/CP2/checkpoints/sts_hyper.ckpt2.3'

# %%
all_checkpoints = [ckpt1, ckpt2, ckpt3, ckpt4]

for checkpoint in all_checkpoints:
    loaded_ckpt = torch.load(checkpoint)
    model, optimizer, scheduler = initializer(train_dataloader, 1)
    model.load_state_dict(loaded_ckpt['model_state_dict'])
    #model.load_state_dict(torch.load(checkpoint, map_location=device))
    pearson_score, fonescore = predict(model, test_dataloader)
    print(f'{checkpoint[44:]} pearsonr: {pearson_score}, f1_score: {fonescore}')
# Out:
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# Finishing last run (ID:jezbg7qk) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">misty-sweep-3</strong>: <a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">https://wandb.ai/iljf/sts_r3/runs/jezbg7qk</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220531_104450-jezbg7qk/logs</code>
# Successfully finished last run (ID:jezbg7qk). Initializing new run:<br/>
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220531_104557-jezbg7qk</code>
# Syncing run <strong><a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">misty-sweep-3</a></strong> to <a href="https://wandb.ai/iljf/sts_r3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h" target="_blank">https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h</a>
# Some weights of the model checkpoint at klue/roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# total step: 489
# yper.ckpt2.0 pearsonr: tensor([0.8687]), f1_score: 0.8313253012048193
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# Finishing last run (ID:jezbg7qk) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">misty-sweep-3</strong>: <a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">https://wandb.ai/iljf/sts_r3/runs/jezbg7qk</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220531_104557-jezbg7qk/logs</code>
# Successfully finished last run (ID:jezbg7qk). Initializing new run:<br/>
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220531_104619-jezbg7qk</code>
# Syncing run <strong><a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">misty-sweep-3</a></strong> to <a href="https://wandb.ai/iljf/sts_r3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h" target="_blank">https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h</a>
# Some weights of the model checkpoint at klue/roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# total step: 489
# yper.ckpt2.1 pearsonr: tensor([0.8739]), f1_score: 0.8316831683168316
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# Finishing last run (ID:jezbg7qk) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">misty-sweep-3</strong>: <a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">https://wandb.ai/iljf/sts_r3/runs/jezbg7qk</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220531_104619-jezbg7qk/logs</code>
# Successfully finished last run (ID:jezbg7qk). Initializing new run:<br/>
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220531_104642-jezbg7qk</code>
# Syncing run <strong><a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">misty-sweep-3</a></strong> to <a href="https://wandb.ai/iljf/sts_r3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h" target="_blank">https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h</a>
# Some weights of the model checkpoint at klue/roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# total step: 489
# yper.ckpt2.2 pearsonr: tensor([0.8792]), f1_score: 0.828125
# Changes to your `wandb` environment variables will be ignored because your `wandb` session has already started. For more information on how to modify your settings with `wandb.init()` arguments, please refer to <a href="https://wandb.me/wandb-init" target="_blank">the W&B docs</a>.
# Finishing last run (ID:jezbg7qk) before initializing another...
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">misty-sweep-3</strong>: <a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">https://wandb.ai/iljf/sts_r3/runs/jezbg7qk</a><br/>Synced 5 W&B file(s), 1 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220531_104642-jezbg7qk/logs</code>
# Successfully finished last run (ID:jezbg7qk). Initializing new run:<br/>
# Tracking run with wandb version 0.12.17
# Run data is saved locally in <code>/content/wandb/run-20220531_104706-jezbg7qk</code>
# Syncing run <strong><a href="https://wandb.ai/iljf/sts_r3/runs/jezbg7qk" target="_blank">misty-sweep-3</a></strong> to <a href="https://wandb.ai/iljf/sts_r3" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h" target="_blank">https://wandb.ai/iljf/sts_r3/sweeps/l3jcjy8h</a>
# Some weights of the model checkpoint at klue/roberta-base were not used when initializing RobertaModel: ['lm_head.layer_norm.bias', 'lm_head.layer_norm.weight', 'lm_head.decoder.weight', 'lm_head.decoder.bias', 'lm_head.dense.bias', 'lm_head.bias', 'lm_head.dense.weight']
# - This IS expected if you are initializing RobertaModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaModel were not initialized from the model checkpoint at klue/roberta-base and are newly initialized: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# total step: 489
# yper.ckpt2.3 pearsonr: tensor([0.8799]), f1_score: 0.825147347740668
